# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
train=pd.read_csv('train.csv')

test=pd.read_csv('test.csv')

# %%
train.shape
# Out:
# (1460, 81)

# %%
#train.head
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#Check null values train
train.isnull().sum().sort_values()
# Out:
# Id                  0
# TotalBsmtSF         0
# Heating             0
# SaleCondition       0
# CentralAir          0
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# SaleType            0
# YrSold              0
# MoSold              0
# MiscVal             0
# PoolArea            0
# ScreenPorch         0
# BsmtUnfSF           0
# 3SsnPorch           0
# OpenPorchSF         0
# WoodDeckSF          0
# PavedDrive          0
# GarageArea          0
#                  ...
# YearBuilt           0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# ExterQual           0
# ExterCond           0
# Foundation          0
# MSSubClass          0
# YearRemodAdd        0
# ...

# %%
#Check null values test
test.isnull().sum().sort_values()
# Out:
# Id                  0
# Foundation          0
# HeatingQC           0
# CentralAir          0
# Electrical          0
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# ExterCond           0
# KitchenAbvGr        0
# Fireplaces          0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# YrSold              0
# TotRmsAbvGrd        0
# ExterQual           0
# Heating             0
# SaleCondition       0
# OverallQual         0
#                  ...
# Exterior1st         1
# SaleType            1
# TotalBsmtSF         1
# BsmtUnfSF           1
# Exterior2nd         1
# BsmtFinSF1          1
# BsmtFinSF2          1
# BsmtFullBath        2
# Functional          2
# Utilities           2
# ...

# %%
#Plotje omdat het kan
plt.figure(figsize=(18, 5))
sns.heatmap(train.isnull(), cbar=False, cmap='viridis')
plt.xlabel("Features", size=14, weight="bold")
plt.title("Places of missing values in column",fontweight="bold",size=14)
plt.show()

# %%
#null values verwijderen
train = train.drop(columns=['PoolQC','MiscFeature','Alley','Fence'],axis=1)
test = test.drop(columns=['PoolQC','MiscFeature','Alley','Fence'],axis=1)
print('Done dropping null values')
# Out:
# Done dropping null values

# %%
#train.head()
#test.head()
test.shape
# Out:
# (1459, 76)

# %%
#Voordat we get_dummies gebruiken soorten we alle columns met text categorie
cat_train = [x for x in train.columns if train[x].dtype=='object']
cat_test = [x for x in test.columns if test[x].dtype=='object']
print('split cat/num done')
# Out:
# split cat/num done

# %%
#text omzetten naar nummers / One-hot encoding met panda's dummies
dummie_train = pd.get_dummies(train, columns=cat_train, drop_first=True)
dummie_test = pd.get_dummies(test, columns=cat_test, drop_first=True)
dummie_train
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# 5        6          50         85.0    14115            5            5
# 6        7          20         75.0    10084            8            5
# 7        8          60          NaN    10382            7            6
# 8        9          50         51.0     6120            7            5
# 9       10         190         50.0     7420            5            6
# 10      11          20         70.0    11200            5            5
# 11      12          60         85.0    11924            9            5
# ...
